# %%
import pandas as pd
import numpy as np

# %%
statistics1 = pd.read_excel('Descrip_Stats_problem_data.xlsx',sheet_name='Problem1')

# %%
statistics1
# Out:
#    No of Commercials (x)  Sales Volume (K$) (y)
# 0                      2                   50.0
# 1                      5                   57.0
# 2                      1                   41.0
# 3                      3                   54.0
# 4                      4                   54.0
# 5                      1                   38.0
# 6                      5                   63.0
# 7                      3                   48.0
# 8                      4                   59.0
# 9                      2                   46.0
# 10                   NaN                    NaN
# 11                   NaN                    NaN
# 12            Covariance                    NaN
# 13           correlation                    NaN

# %%
statistics1.dropna(axis=0,inplace=True)
statistics1
# Out:
#   No of Commercials (x)  Sales Volume (K$) (y)
# 0                     2                   50.0
# 1                     5                   57.0
# 2                     1                   41.0
# 3                     3                   54.0
# 4                     4                   54.0
# 5                     1                   38.0
# 6                     5                   63.0
# 7                     3                   48.0
# 8                     4                   59.0
# 9                     2                   46.0

# %%
statistics1['No of Commercials (x)']=statistics1['No of Commercials (x)'].astype(float)

# %%
statistics1.cov()
# Out:
#                        No of Commercials (x)  Sales Volume (K$) (y)
# No of Commercials (x)               2.222222              11.000000
# Sales Volume (K$) (y)              11.000000              62.888889

# %%
statistics1['No of Commercials (x)'].cov(statistics1['Sales Volume (K$) (y)'])
# Out:
# 11.0

# %%
statistics1.corr()
# Out:
#                        No of Commercials (x)  Sales Volume (K$) (y)
# No of Commercials (x)               1.000000               0.930491
# Sales Volume (K$) (y)               0.930491               1.000000

# %%
statistics1['No of Commercials (x)'].corr(statistics1['Sales Volume (K$) (y)'])
# Out:
# 0.9304905807411791

# %%
statistics2 = pd.read_excel('Descrip_Stats_problem_data.xlsx',sheet_name='Problem2')

# %%
statistics2
# Out:
#    No of Commercials (x)  Sales Volume ($) (y)
# 0                      2               50000.0
# 1                      5               57000.0
# 2                      1               41000.0
# 3                      3               54000.0
# 4                      4               54000.0
# 5                      1               38000.0
# 6                      5               63000.0
# 7                      3               48000.0
# 8                      4               59000.0
# 9                      2               46000.0
# 10                   NaN                   NaN
# 11                   NaN                   NaN
# 12            Covariance                   NaN
# 13           correlation                   NaN

# %%
statistics2.dropna(axis=0,inplace=True)
statistics2
# Out:
#   No of Commercials (x)  Sales Volume ($) (y)
# 0                     2               50000.0
# 1                     5               57000.0
# 2                     1               41000.0
# 3                     3               54000.0
# 4                     4               54000.0
# 5                     1               38000.0
# 6                     5               63000.0
# 7                     3               48000.0
# 8                     4               59000.0
# 9                     2               46000.0

# %%
statistics2['No of Commercials (x)']=statistics2['No of Commercials (x)'].astype(float)

# %%
statistics2['No of Commercials (x)'].cov(statistics2['Sales Volume ($) (y)'])
# Out:
# 11000.0

# %%
statistics2['No of Commercials (x)'].corr(statistics2['Sales Volume ($) (y)'])
# Out:
# 0.930490580741179

# %%
statistics3 = pd.read_excel('Descrip_Stats_problem_data.xlsx',sheet_name='Problem3')

# %%
statistics3.set_value(7,'Sales',41000)
# Out:
# C:\Users\Srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
#              State  Sales
# 0         Arizona    8408
# 1      California    1374
# 2        Colorado    1872
# 3         Florida    8879
# 4         Georgia    2459
# 5          Kansas   11413
# 6        Kentucky     608
# 7             Ohio  41000
# 8        Maryland    6452
# 9   Massachusetts    1850
# 10       Michigan    2818
# 11    Mississippi    1356
# 12       Missouri   10498
# 13     New Jersey    7478
# 14      Louisiana    4019
# 15       Oklahoma    4341
# 16      Tennessee     739
# 17          Texas    2127
# 18       Virginia    3653
# 19     Washington    5794
# 20  West Virginia    8305

# %%
statistics3.boxplot('Sales')

# %%
statistics3.set_value(7,'Sales',14138)
# Out:
# C:\Users\Srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
#              State  Sales
# 0         Arizona    8408
# 1      California    1374
# 2        Colorado    1872
# 3         Florida    8879
# 4         Georgia    2459
# 5          Kansas   11413
# 6        Kentucky     608
# 7             Ohio  14138
# 8        Maryland    6452
# 9   Massachusetts    1850
# 10       Michigan    2818
# 11    Mississippi    1356
# 12       Missouri   10498
# 13     New Jersey    7478
# 14      Louisiana    4019
# 15       Oklahoma    4341
# 16      Tennessee     739
# 17          Texas    2127
# 18       Virginia    3653
# 19     Washington    5794
# 20  West Virginia    8305

# %%
statistics3.sort_values('Sales')
# Out:
#              State  Sales
# 6        Kentucky     608
# 16      Tennessee     739
# 11    Mississippi    1356
# 1      California    1374
# 9   Massachusetts    1850
# 2        Colorado    1872
# 17          Texas    2127
# 4         Georgia    2459
# 10       Michigan    2818
# 18       Virginia    3653
# 14      Louisiana    4019
# 15       Oklahoma    4341
# 19     Washington    5794
# 8        Maryland    6452
# 13     New Jersey    7478
# 20  West Virginia    8305
# 0         Arizona    8408
# 3         Florida    8879
# 12       Missouri   10498
# 5          Kansas   11413
# 7             Ohio  14138

# %%
statistics3['Percentile_rank']=statistics3.Sales.rank(pct=True)

# %%
statistics3
# Out:
#              State  Sales  Percentile_rank
# 0         Arizona    8408         0.809524
# 1      California    1374         0.190476
# 2        Colorado    1872         0.285714
# 3         Florida    8879         0.857143
# 4         Georgia    2459         0.380952
# 5          Kansas   11413         0.952381
# 6        Kentucky     608         0.047619
# 7             Ohio  14138         1.000000
# 8        Maryland    6452         0.666667
# 9   Massachusetts    1850         0.238095
# 10       Michigan    2818         0.428571
# 11    Mississippi    1356         0.142857
# 12       Missouri   10498         0.904762
# 13     New Jersey    7478         0.714286
# 14      Louisiana    4019         0.523810
# 15       Oklahoma    4341         0.571429
# 16      Tennessee     739         0.095238
# 17          Texas    2127         0.333333
# 18       Virginia    3653         0.476190
# 19     Washington    5794         0.619048
# 20  West Virginia    8305         0.761905

# %%
WashingtonPercen=statistics3[statistics3['State']=='Washington ']['Percentile_rank']
WashingtonPercen
# Out:
# 19    0.619048
# Name: Percentile_rank, dtype: float64

# %%
statistics3[statistics3['Percentile_rank']>WashingtonPercen.sum()].count().max()
# Out:
# 8

# %%
#statistics3[statistics3.Percentile_rank.isin([0.857143])]
#statistics3.Sales.rank(pct=True).sort_values()
statistics3[statistics3['Sales']==np.percentile(statistics3.Sales,85)]
#np.percentile(statistics3.Sales,85)
# Out:
#       State  Sales  Percentile_rank
# 3  Florida    8879         0.857143

# %%
statistics4 = pd.read_excel('Descrip_Stats_problem_data.xlsx',sheet_name='Problem4')

# %%
statistics4.boxplot()

# %%
statistics4.describe()
# Out:
#          Player A   Player B
# count   20.000000  20.000000
# mean    35.000000  35.000000
# std     20.206825  25.296141
# min      7.000000   0.000000
# 25%     24.000000  17.000000
# 50%     35.000000  31.000000
# 75%     40.500000  53.250000
# max    100.000000  93.000000

# %%
statistics4.set_value(6,'Player A',40)
# Out:
# C:\Users\Srini\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
#     Player A  Player B
# 0         25         0
# 1         40        25
# 2         38        22
# 3         48        38
# 4         51        25
# 5         35        45
# 6         40        51
# 7         25        60
# 8         15        62
# 9         20        93
# 10        21        68
# 11        25        63
# 12        35        42
# 13        40         9
# 14         7         3
# 15        12         5
# 16        25        20
# 17        40        14
# 18        42        18
# 19        56        37

# %%
statistics4.boxplot()

# %%
statistics4.describe()
# Out:
#         Player A   Player B
# count  20.000000  20.000000
# mean   32.000000  35.000000
# std    13.333772  25.296141
# min     7.000000   0.000000
# 25%    24.000000  17.000000
# 50%    35.000000  31.000000
# 75%    40.000000  53.250000
# max    56.000000  93.000000
